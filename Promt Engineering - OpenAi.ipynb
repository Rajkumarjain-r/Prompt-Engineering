# %%
import os
import sys

import openai
from langchain.chains import ConversationalRetrievalChain, RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.indexes import VectorstoreIndexCreator
from langchain.indexes.vectorstore import VectorStoreIndexWrapper
from langchain.llms import OpenAI
from langchain.vectorstores import Chroma
import constants
from pydantic import BaseSettings
import chromadb

# %%
os.environ["OPENAI_API_KEY"] = constants.apikey

# %%
# Enable to save to disk & reuse the model (for repeated queries on the same data)
PERSIST = False

#query = None
#if len(sys.argv) > 1:
#  query = sys.argv[1]

query = input("Enter your query")
print(query)
#query = 'summarize the context of the data'

   
if PERSIST and os.path.exists("persist"):
  print("Reusing index...\n")
  vectorstore = Chroma(persist_directory="persist", embedding_function=OpenAIEmbeddings())
  index = VectorStoreIndexWrapper(vectorstore=vectorstore)
else:
  loader = TextLoader("history_search_text.txt",encoding = 'utf-8') # Use this line if you only need data.txt
  #loader = DirectoryLoader(".",glob="*.txt")
  if PERSIST:
    index = VectorstoreIndexCreator(vectorstore_kwargs={"persist_directory":"persist"}).from_loaders([loader])
  else:
    index = VectorstoreIndexCreator().from_loaders([loader])

chain = ConversationalRetrievalChain.from_llm(
  llm=ChatOpenAI(model="gpt-3.5-turbo"),
  retriever=index.vectorstore.as_retriever(search_kwargs={"k": 1}),
)

chat_history = []
while True:
  if not query:
    query = input("Prompt: ")
  if query in ['quit', 'q', 'exit']:
    sys.exit()
  result = chain({"question": query, "chat_history": chat_history})
  print(result['answer'],end='\n')

  chat_history.append((query, result['answer']))
  query = None
# Out:
# Enter your queryeducation details of Manish Sainani
# education details of Manish Sainani
# I'm sorry, but I couldn't find any specific information about the education details of Manish Sainani.
# Prompt: who is the founder of Hushh?
# The founder of Hushh is Manish Sainani.
# Prompt: Tell about Hush
# Hush is a privacy-focused messaging platform that prioritizes secure and encrypted communication. It aims to provide a secure environment for individuals to send messages, make calls, and share files without compromising their privacy. Hush utilizes end-to-end encryption to ensure that only the intended recipients can access the messages and files. It also offers features like self-destructing messages and anonymous chat rooms. For more detailed information, you can visit their official website at https://www.hushapp.io/.
# Prompt: Is there phone no of him?
# Manish Sainani's phone number is either 980-776-1000, 214-509-3686, or 425-214-1343.
# Prompt: Is there phone no of him?
# Manish Sainani's phone number is either 980-776-1000, 214-509-3686, or 425-214-1343.
# Prompt: Prompt: Is there email id of Manish or hushh so that I can mail ?
# Yes, I have two email addresses for Manish Sainani. The first one is manish@hush1one.com and the second one is manish.sainani@gmail.com.
# Prompt: what are the skills of Manish Sainani
# Manish Sainani has effective project and program management skills, particularly in strategic planning, product planning, and development.
# Prompt: where is Hushh head quaters?
# I'm sorry, but I don't have access to the internet to provide up-to-date information on the headquarters of Hushh.
# Prompt: Is must be in the data do a research
# Based on the available information, the headquarters of Hushh is located in Kirkland, Washington, United States.
# Prompt: what are the data that is been searched with respect to datascien python programming in this data
# Based on the given context, it is not possible to determine what specific data has been searched regarding data science and Python programming in this conversation. The information provided does not include any details about the specific searches or topics discussed.
# Prompt: what is the conetxt of the data
# I'm sorry, but I don't have enough information to answer your question. Could you please provide more specific details or context?
# Prompt: data sciecne
# The specific data searched regarding data science is not mentioned in the given context.
# Prompt: Is there anything about python
# Yes, the given context is a Google search query about the "__init__" method in Python.
# Prompt: what are websites that are used
# The websites used in the given context are:
#
# 1. https://www.google.com/url?q=https://fa-erwh-saasfaprod1.fa.ocs.oraclecloud.com:443/hcmUI/CandidateExperience/en/sites/CX_2/requisitions?selectedCategoriesFacet%3D300000622651234%26selectedLocationsFacet%3D300000002875750%26sortBy%3DPOSTING_DATES_DESC&source=gmail&ust=1687826725597000&usg=AOvVaw1cUucGrkaxiG5P3BPiA--o
# 2. https://www.google.com/search?q=ineuron.ai+google+review&oq=in&gs_lcrp=EgZjaHJvbWUqBggGEEUYOzIGCAAQRRg8MgYIARBFGDwyBggCEEUYPDIGCAMQRRhBMgYIBBBFGEEyBggFEEUYOTIGCAYQRRg7MgkIBxAjGCcYigUyBggIEEUYOzINCAkQABiDARixAxiABNIBCDE5ODRqMGo0qAIAsAIA&client=ms-android-oppo-rvo3&sourceid=chrome-mobile&ie=UTF-8
# 3. https://www.britannica.com/topic/Titanic
# 4. https://us06web.zoom.us/j/88462517333
# 5. https://learn.pwskills.com/lesson/24th-June-Doubt-Session/6496eaad6977cc37a4e15cb7/course/Data-Science-Masters-2.0/64207e5daf09d6280f5654d0
# 6. https://learn.pwskills.com/lesson/Tuples/646249086977cc6d6cddf478/course/Data-Science-Masters-2.0/64207e5daf09d6280f5654d0
# Prompt: summarize the data
# I'm sorry, but there was no specific data searched regarding data science and Python programming in this conversation.
# Prompt: what are some searches that are done
# There are no specific searches mentioned in this conversation.
# Prompt: tell me about Hushh
# I'm sorry, but I don't have any information about "Hushh" based on the context provided. It could refer to a person, a brand, a product, or something else entirely. Can you please provide more specific details or context so I can assist you better?
# Prompt: tell me about Hushh.ai
# I'm sorry, but I couldn't find any information about Hushh.ai. It's possible that you may be referring to a different company or product.
# Prompt: summarize the data that is used
# I'm sorry, but I don't have access to the specific data used in the conversation.
# Prompt: what is the context of the data that is been used
# I'm sorry, but I don't have access to any information about the context of the data that has been used.
# Prompt: give few pointers
# I'm sorry, but I don't have access to the specific content of the link you provided. If you could provide more information or specify what kind of pointers you are looking for, I'll do my best to help you.
# Prompt: Is Amazon website used here
# No, the Amazon website was not used in this conversation.
# Prompt: how many different websites have been used
# There have been 15 different websites used in this conversation.
# Prompt: what is the conversation about
# I'm sorry, but I don't have enough information to determine the specific topic of the conversation.
# Prompt: is this about data science?
# Yes, this conversation is about data science.
